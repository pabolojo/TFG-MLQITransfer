# %%
H = {{\[CapitalDelta]/2, J}, {J, -\[CapitalDelta]/2}};
MatrixForm[H]
# Out:
# Δ
# -
# 2        J
#
#            1
#          -(-) Δ
# J          2

# %%
FullSimplify[MatrixExp[-I H t], \[CapitalDelta] == 0];
expm = FullSimplify[MatrixExp[-I H t]];
psi0 = {1, 0};

psit = expm . psi0;

FullSimplify[psit Conjugate[psit], Assumptions ->{\[CapitalDelta]>0, J>0, t>0}]
# Out:
#     2    2      2               2    2        2                     2    2
#  2 J  + Δ  + 2 J  Cos[t Sqrt[4 J  + Δ ]]  -2 J  (-1 + Cos[t Sqrt[4 J  + Δ ]])
# {---------------------------------------, -----------------------------------}
#                    2    2                                 2    2
#                 4 J  + Δ                               4 J  + Δ

# %%
ev = Eigenvectors[H];
MatrixForm[ev]
eval = Eigenvalues[H]
# Out:
#                   2    2
#   1  -Δ + Sqrt[4 J  + Δ ]
# -(-) --------------------
#   2           J             1
#
#                   2    2
#   1  -Δ - Sqrt[4 J  + Δ ]
# -(-) --------------------
#   2           J             1
#                                2    2
#    1          2    2   Sqrt[4 J  + Δ ]
# {-(-) Sqrt[4 J  + Δ ], ---------------}
#    2                          2

# %%
a = psi0;
b = ev[[1]];

c0 = Norm[(a.b)/Norm[b]^2 b]

b = ev[[2]];
c1 = Norm[(a.b)/Norm[b]^2 b]
# Out:
#                              2    2
#                 -Δ + Sqrt[4 J  + Δ ]        2
#      Abs[----------------------------------]
#                                  2    2
#                     -Δ + Sqrt[4 J  + Δ ] 2
#                 Abs[--------------------]
#                              J
#          J (1 + --------------------------)
#                             4
# Sqrt[---------------------------------------- +
#                         4
#
#                              2    2  2
#                (-Δ + Sqrt[4 J  + Δ ])        2
#      Abs[-----------------------------------]
#                                   2    2
#                      -Δ + Sqrt[4 J  + Δ ] 2
#                  Abs[--------------------]
#           2                   J
#          J  (1 + --------------------------)
#                              4
# >    -----------------------------------------]
#                         16
#                              2    2
# ...

# %%
psit = c0 Exp[I J t] ev[[1]] + c1 Exp[-I J t] ev[[2]]
# Out:
#                                                            2    2
#                                               -Δ - Sqrt[4 J  + Δ ]        2
#                                    Abs[----------------------------------]
#                                                                2    2
#                                                   -Δ - Sqrt[4 J  + Δ ] 2
#                                               Abs[--------------------]
#                                                            J
#                                        J (1 + --------------------------)
#    1                 2    2                               4
# {-(-) ((-Δ - Sqrt[4 J  + Δ ]) Sqrt[---------------------------------------- +
#    2                                                  4
#
#                                    2    2  2
#                      (-Δ - Sqrt[4 J  + Δ ])        2
#            Abs[-----------------------------------]
#                                         2    2
# ...

# %%
J = 1;
psit
# Out:
#                                                         2
#                                          -Δ - Sqrt[4 + Δ ]      2
#                                 Abs[---------------------------]
#                                                            2  2
#                                         Abs[-Δ - Sqrt[4 + Δ ]]
#                                     1 + -----------------------
#    1                   2                           4
# {-(-) ((-Δ - Sqrt[4 + Δ ]) Sqrt[--------------------------------- +
#    2                                            4
#
#                                   2  2
#                   (-Δ - Sqrt[4 + Δ ])      2
#            Abs[---------------------------]
#                                       2  2
#                    Abs[-Δ - Sqrt[4 + Δ ]]
#                1 + -----------------------
#                               4                   I t
# >          ---------------------------------]) / E    -
#                           16
#
# ...

# %%
psitA = expm . psi0
# Out:
#                                            2                           2
#                                t Sqrt[4 + Δ ]              t Sqrt[4 + Δ ]
#                  2     I Δ Sin[--------------]  (-2 I) Sin[--------------]
#      t Sqrt[4 + Δ ]                  2                           2
# {Cos[--------------] - -----------------------, --------------------------}
#            2                          2                          2
#                             Sqrt[4 + Δ ]               Sqrt[4 + Δ ]
